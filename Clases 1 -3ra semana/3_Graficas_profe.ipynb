# %% [markdown]
# # Librerias

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import network as nx

# %% [markdown]
# # Datos

# %%
np.random.seed(0)
categorias = ["cat_A", "cat_B", "cat_C", "cat_D"]
valores = np.random.randint(10,50, size=4)
fechas = np.linspace(2010, 2025, num=10)
datos_temporales = np.random.randn(10)*100
matrix = np.random.randn(10,10)

# %% [markdown]
# # Grafico de barras

# %%
plt.figure(figsize=(8,6))
plt.barh(categorias, valores, color='skyblue')
plt.title('Grafico de Barras')
plt.xlabel('Valores')
plt.ylabel('Categoricas');

# %% [markdown]
# # Grafico de lineas

# %%
plt.figure(figsize=(8,6))
plt.plot(fechas, datos_temporales, color='red', marker='o')
plt.title('Grafico de Lineas')
plt.xlabel('Valores')
plt.ylabel('TIempo');

# %% [markdown]
# # Grafico Mapa de calor

# %%
plt.figure(figsize=(8,6))
sns.heatmap(matrix, annot=True)
plt.title('Mapa de Calor');

# %% [markdown]
# # Grafico Diagrama de Dispersion

# %%
datos_dipersion = np.random.randn(100,2)*100

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(datos_dipersion)
plt.title('Grafico de Dispersion')
plt.xlabel('Variable_X (PCA_1)')
plt.ylabel('Variable_Y (PCA_2)');

# %% [markdown]
# # Grafico de Red

# %%
import networkx as nx

# %%
n = 10
p = 0.5
G = nx.erdos_renyi_graph(n,p)

# %%
nx.draw(G,node_color='skyblue', with_labels=True)

# %% [markdown]
# # Librerias 2.0

# %%
import pandas as pd 
import plotly.express as px
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc

plt.rcParams['figure.figsize'] = (8,6)

# %%
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns= iris.feature_names)

# %%
df['species'] = iris.target

# %%
df['species_name'] = df['species'].map({0:'setosa', 1:'virginica', 2:'versicolor'})

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species species_name
# ...

# %% [markdown]
# # Histogramas

# %%
plt.figure(figsize=(15,5))
for i, feature in enumerate(iris.feature_names):
    plt.subplot(1,4, i+1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribucion de {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Grafica de Caja y vigote

# %%
plt.figure(figsize=(15,5))
for i, feature in enumerate(iris.feature_names):
    plt.subplot(1,4, i+1)
    sns.boxplot(y=df[feature], x=df['species_name'])
    plt.title(f'{feature} por Especie')
    plt.xlabel('Especie')
    plt.ylabel(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Grafico de Dispersion

# %%
df.head(2)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
#
#    species species_name
# 0        0       setosa
# 1        0       setosa

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df, x="sepal length (cm)", y='sepal width (cm)', s=100, alpha=0.8, hue='species_name')
plt.title('Longitud vs Ancho del Sepalo por Especie')
plt.xlabel('Longitud del Sepalo (cm)')
plt.ylabel('Ancho del Sepalo (cm)')
plt.legend(title="Especie")
plt.show()

# %%
sns.pairplot(df, hue="species_name")
plt.suptitle("Pait plot de caracteristicas de Iris por Especie")
plt.show()
